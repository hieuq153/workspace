# %% [markdown]
# Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi n

# %%
n = int(input("Nhập n:"))
print(n*2)
# Out:
# 10

# %% [markdown]
# Bài 2: Tính diện tích phần còn lại

# %%
a = float(input("Nhập chiều rộng:"))
b = float(input("Nhập chiều dài:"))

r = a/2
S_hcn = a * b
S_tron = 3.14 * (r ** 2)
S = S_hcn - S_tron
print(S)
# Out:
# 30.375

# %% [markdown]
# Bài 3: Chuyển đổi Hoa - thường:

# %%
a = input("Nhập kí tự:")

if a.isupper():
    print(a.lower())
else:
    print(a.upper())
# Out:
# H

# %% [markdown]
# Bài 4: Kiểm tra kí tự alphabet:

# %%
a = input("Nhập kí tự:")

if a.isalpha():
    print("Đây là chữ cái thuộc alphabet.")
else:
    print("Đây không phải là chữ cái thuộc alphabet.")
# Out:
# Đây là chữ cái thuộc alphabet.

# %% [markdown]
# Bài 5: Tìm chữ cái liền trước.

# %%
a = input("Nhập kí tự:")

if 65<ord(a)<=90:
    print(chr(ord(a)+31))
elif ord(a) == 65:
    print("z")
# Out:
# g

# %% [markdown]
# Bài 6: Tính diện tích tam giác

# %%
a = float(input("Nhập cạnh 1:"))
b = float(input("Nhập cạnh 2:"))   
c = float(input("Nhập cạnh 3:"))

if a + b > c and a + c > b and b + c > a:
    print("Đây là 3 cạnh của một tam giác.")
    p = (a + b + c) / 2
    S = (p * (p - a) * (p - b) * (p - c)) ** 0.5
    print("Diện tích tam giác là:", S)
else:
    print("Đây không phải là 3 cạnh của một tam giác.")
# Out:
# Đây là 3 cạnh của một tam giác.
# Diện tích tam giác là: 6.0

# %% [markdown]
# Bài 7: Tìm giá trị của vị trí thứ 5 và 9 của dãy kí tự.

# %%
a = input("Dãy kí tự dài hơn hoặc bằng 20 kí tự:")

if len(a) >= 20:
    print(f"Kí tự thứ 5: {a[4]}")
    print(f"Kí tự thứ 9: {a[8]}")
else:
    print("Dãy kí tự không đủ 20 kí tự.")
# Out:
# Kí tự thứ 5: d
# Kí tự thứ 9: a

# %% [markdown]
# Bài 8: Tính tiền điện:

# %%
ho_ten = input("Nhập họ tên:")
a = float(input("Chỉ số tháng trước:"))
b = float(input("Chỉ số tháng này:"))

c = b - a

if c <= 50:
    d = c * 1984
elif c <= 100:
    d = 50 * 1984 + (c - 50) * 2050
elif c <= 200:
    d = 50 * 1984 + 50 * 2050 + (c - 100) * 2380
elif c <= 300:
    d = 50 * 1984 + 50 * 2050 + 100 * 2380 + (c - 200) * 2998
elif c <= 400:
    d = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + (c - 300) * 3350
else:
    d = 50 * 1984 + 50 * 2050 + 100 * 2380 + 100 * 2998 + 100 * 3350 + (c - 400) * 3460

e = d * 1.08

print(f"Họ tên: {ho_ten}")
print(f"Tiền điện phải trả: {round(e)} đồng")
# Out:
# Họ tên: Nguyen Xuan Hai
# Tiền điện phải trả: 1855505 đồng

# %% [markdown]
# Bài tập bổ trợ

# %% [markdown]
# Bài 1: Kiểm tra tính chẵn lẻ.

# %%
a = int(input("Nhập một số nguyên:"))
if a % 2 == 0 :
    print(f"{a} là số chẵn.")
else:
    print(f"{a} là số lẻ.")
# Out:
# 7 là số lẻ.

# %% [markdown]
# Bài 2: Kiểm tra chữ số tận cùng có phải số 5 không?

# %%
a = int(input("Nhập một số nguyên:"))
if str(a)[-1] in "5":
    print(f"{a} là số kết thúc bằng 5.")
else:
    print(f"{a} không phải là số kết thúc bằng 5.")
# Out:
# 1333 không phải là số kết thúc bằng 5.

# %% [markdown]
# Bài 3: Kiểm tra số chia hết cho 3 và 5.

# %%
a = int(input("Nhập một số nguyên:"))
if a % 3 == 0 and a % 5 == 0:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# Bài 4: Kiểm tra tuổi bầu cử.

# %%
a = int(input("Nhập năm sinh"))
if 2026 - a < 18:
    print("Bạn chưa đủ tuổi bầu cử")
else:
    print("Bạn đã đủ tuổi bầu cử")
# Out:
# Bạn đã đủ tuổi bầu cử

# %% [markdown]
# Bài 5: So sánh 2 số a và b

# %%
a = float(input("Nhập số thực a:"))
b = float(input("Nhập số thực b:"))

if a > b:
    print(f"{a} lớn hơn {b}.")
elif a < b:
    print(f"{a} nhỏ hơn {b}.")
else:
    print(f"{a} bằng {b}.")
# Out:
# 13.0 nhỏ hơn 20.0.

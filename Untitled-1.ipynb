# %% [markdown]
# Bai 1: In ra dong chu: "Hello world"

# %%
print("Hello world", end="\n")
print("Hello world")
print("Hello world", "Hello world", sep=" ", end="\n")
print("Hello world", "Hello world", sep=",", end="\n")
print("Hello world", "Hello world", sep="e", end="_")
print("Hello world", "Hello world", sep="e", end="_")
# Out:
# Hello world
# Hello world
# Hello world Hello world
# Hello world,Hello world
# Hello worldeHello world_Hello worldeHello world_

# %% [markdown]
# Bai 2: Ham input trong python

# %% [markdown]
# Bai 3: Cac phep toan co ban
